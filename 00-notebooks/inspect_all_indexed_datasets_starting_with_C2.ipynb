# %% [markdown]
# # Verify Indexed Datasets

# %%
import datacube

# %%
dc = datacube.Datacube()
# Out:
# Failed to resolve driver datacube.plugins.index::s3aio_index
# Error was: ContextualVersionConflict(botocore 1.14.8 (/usr/local/lib/python3.6/dist-packages), Requirement.parse('botocore<1.13.0,>=1.12.117'), {'boto3'})

# %%
dc.list_products()
# Out:
#                   name                               description fmask_water  \
# id
# 1   usgs_ls8c_level2_2  Sample USGS Level 2 Collection 2 Landsat        None
#
#    creation_time gqa_abs_iterative_mean_x format gqa_mean_xy fmask_clear  \
# id
# 1           None                     None   None        None        None
#
#    gqa_mean_x region_code  ... gqa_abs_xy gqa_stddev_xy dataset_maturity  \
# id                         ...
# 1        None        None  ...       None          None             None
#
#    gqa_stddev_y gqa_abs_iterative_mean_y gqa_iterative_stddev_xy crs  \
# id
# 1          None                     None                    None NaN
#
#    resolution tile_size spatial_dimensions
# id
# 1         NaN       NaN                NaN
#
# [1 rows x 45 columns]

# %%
dir(dc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_dask_load',
#  '_list_measurements',
#  '_xr_load',
#  'close',
#  'create_storage',
#  'find_datasets',
#  'find_datasets_lazy',
#  'group_datasets',
#  'index',
#  'list_measurements',
#  'list_products',
#  'load',
#  'load_data',
#  'measurement_data']

# %%
dc.list_measurements()
# Out:
#                                                                      aliases  \
# product            measurement
# usgs_ls8c_level2_2 coastal_aerosol                              [b1, band_1]
#                    blue                                         [b2, band_2]
#                    green                                        [b3, band_3]
#                    red                                          [b4, band_4]
#                    nir                                          [b5, band_5]
#                    swir_1                                [b6, band_6, swir1]
#                    swir_2                                [b7, band_7, swir2]
#                    surface_temperature                [b10, band_10, st_b10]
#                    thermal_radiance                                [st_trad]
#                    upwell_radiance                                 [st_urad]
#                    downwell_radiance                               [st_drad]
#                    atmospheric_transmittance                      [st_atran]
#                    emissivity                                      [st_emis]
#                    emissivity_stdev                                [st_emsd]
#                    cloud_distance                                 [st_cdist]
#                    quality_l2_aerosol                           [aerosol_qa]
#                    quality_l2_surface_temperature                    [st_qa]
#                    quality_l1_pixel                               [pixel_qa]
#                    quality_l1_radiometric_saturation             [radsat_qa]
#
#                                                        dtype  \
# product            measurement
# usgs_ls8c_level2_2 coastal_aerosol                    uint16
#                    blue                               uint16
#                    green                              uint16
#                    red                                uint16
#                    nir                                uint16
#                    swir_1                             uint16
#                    swir_2                             uint16
#                    surface_temperature                uint16
#                    thermal_radiance                    int16
#                    upwell_radiance                     int16
#                    downwell_radiance                   int16
#                    atmospheric_transmittance           int16
#                    emissivity                          int16
#                    emissivity_stdev                    int16
#                    cloud_distance                      int16
#                    quality_l2_aerosol                  uint8
#                    quality_l2_surface_temperature      int16
#                    quality_l1_pixel                   uint16
#                    quality_l1_radiometric_saturation  uint16
#
#                                                                                        flags_definition  \
# product            measurement
# usgs_ls8c_level2_2 coastal_aerosol                                                                  NaN
#                    blue                                                                             NaN
#                    green                                                                            NaN
#                    red                                                                              NaN
#                    nir                                                                              NaN
#                    swir_1                                                                           NaN
#                    swir_2                                                                           NaN
#                    surface_temperature                                                              NaN
#                    thermal_radiance                                                                 NaN
#                    upwell_radiance                                                                  NaN
#                    downwell_radiance                                                                NaN
#                    atmospheric_transmittance                                                        NaN
#                    emissivity                                                                       NaN
#                    emissivity_stdev                                                                 NaN
#                    cloud_distance                                                                   NaN
#                    quality_l2_aerosol                 {'water': {'bits': 2, 'values': {'0': 'not_wat...
#                    quality_l2_surface_temperature                                                   NaN
#                    quality_l1_pixel                   {'snow': {'bits': 5, 'values': {'0': 'not_high...
#                    quality_l1_radiometric_saturation  {'band_1_saturation': {'bits': 0, 'values': {'...
#
#                                                                                    name  \
# product            measurement
# usgs_ls8c_level2_2 coastal_aerosol                                      coastal_aerosol
#                    blue                                                            blue
#                    green                                                          green
#                    red                                                              red
#                    nir                                                              nir
#                    swir_1                                                        swir_1
#                    swir_2                                                        swir_2
#                    surface_temperature                              surface_temperature
#                    thermal_radiance                                    thermal_radiance
#                    upwell_radiance                                      upwell_radiance
#                    downwell_radiance                                  downwell_radiance
#                    atmospheric_transmittance                  atmospheric_transmittance
#                    emissivity                                                emissivity
#                    emissivity_stdev                                    emissivity_stdev
#                    cloud_distance                                        cloud_distance
#                    quality_l2_aerosol                                quality_l2_aerosol
#                    quality_l2_surface_temperature        quality_l2_surface_temperature
#                    quality_l1_pixel                                    quality_l1_pixel
#                    quality_l1_radiometric_saturation  quality_l1_radiometric_saturation
#
#                                                       nodata       units
# product            measurement
# usgs_ls8c_level2_2 coastal_aerosol                         0           1
#                    blue                                    0           1
#                    green                                   0           1
#                    red                                     0           1
#                    nir                                     0           1
#                    swir_1                                  0           1
#                    swir_2                                  0           1
#                    surface_temperature                     0      Kelvin
#                    thermal_radiance                    -9999           1
#                    upwell_radiance                     -9999           1
#                    downwell_radiance                   -9999           1
#                    atmospheric_transmittance           -9999           1
#                    emissivity                          -9999           1
#                    emissivity_stdev                    -9999           1
#                    cloud_distance                      -9999  Kilometers
#                    quality_l2_aerosol                      1   bit_index
#                    quality_l2_surface_temperature      -9999      Kelvin
#                    quality_l1_pixel                        1   bit_index
#                    quality_l1_radiometric_saturation       0   bit_index

# %%
product = 'usgs_ls8c_level2_2'
ds = dc.find_datasets(product=product)

# %%
ds[0]
# Out:
# Dataset <id=f919971c-0900-5ef1-b6f2-b98bb6993190 type=usgs_ls8c_level2_2 location=s3://deafrica-usgs-c2-data/usgs_ls8c_level2_2/157/072/2019/06/12/usgs_ls8c_level2_2-0-20190917_157072_2019-06-12.odc-metadata.yaml>

# %%
ds[0].metadata_doc
# Out:
# {'id': 'f919971c-0900-5ef1-b6f2-b98bb6993190',
#  'crs': 'epsg:32639',
#  'grids': {'default': {'shape': [7751, 7631],
#    'transform': [30.0, 0.0, 344685.0, 0.0, -30.0, -1801785.0, 0.0, 0.0, 1.0]}},
#  'label': 'usgs_ls8c_level2_2-0-20190917_157072_2019-06-12',
#  'extent': {'lat': {'end': -16.29197257738159, 'begin': -18.398860308523574},
#   'lon': {'end': 51.69694710652911, 'begin': 49.52969965051465}},
#  '$schema': 'https://schemas.opendatacube.org/dataset',
#  'lineage': {'source_datasets': {}},
#  'product': {'href': 'https://collections.dea.ga.gov.au/product/usgs_ls8c_level2_2',
#   'name': 'usgs_ls8c_level2_2'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[573615.0, -1801785.0],
#     [344685.0, -1801785.0],
#     [344685.0, -2034315.0],
#     [573615.0, -2034315.0],
#     [573615.0, -1801785.0]]]},
#  'properties': {'eo:gsd': 30.0,
#   'datetime': '2019-06-12T06:39:23.805046',
#   'eo:platform': 'landsat-8',
#   'odc:producer': 'usgs.gov',
#   'eo:instrument': 'OLI_TIRS',
#   'eo:cloud_cover': 19.22,
#   'eo:sun_azimuth': 36.4081371,
#   'landsat:wrs_row': 72,
#   'odc:file_format': 'GeoTIFF',
#   'odc:region_code': '157072',
#   'eo:sun_elevation': 40.314183,
#   'landsat:wrs_path': 157,
#   'landsat:station_id': 'LGN',
#   'odc:product_family': 'level2',
#   'odc:dataset_version': '2.0.20190917',
#   'odc:processing_datetime': '2019-09-17T17:33:17',
#   'landsat:landsat_scene_id': 'LC81570722019163LGN00',
#   'landsat:collection_number': 2,
#   'landsat:landsat_product_id': 'LC08_L1TP_157072_20190612_20190917_02_T1',
#   'landsat:geometric_rmse_model_x': 5.129,
#   'landsat:geometric_rmse_model_y': 6.076,
#   'landsat:ground_control_points_model': 40,
#   'landsat:processing_software_version': 'LPGS_Unknown',
#   'landsat:ground_control_points_version': 51},
#  'accessories': {'checksum:sha1': {'path': 'usgs_ls8c_level2_2-0-20190917_157072_2019-06-12.sha1'},
#   'metadata:processor': {'path': 'usgs_ls8c_level2_2-0-20190917_157072_2019-06-12.proc-info.yaml'},
#   'metadata:landsat_mtl': {'path': 'LC08_L2SP_157072_20190612_20190917_02_T1_MTL.txt'}},
#  'grid_spatial': {'projection': {'valid_data': {'type': 'Polygon',
#     'coordinates': [[[573615.0, -1801785.0],
