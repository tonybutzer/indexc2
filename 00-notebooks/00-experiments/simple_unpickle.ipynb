# %%
import pickle
# open a file, where you stored the pickled data
file = open('meta_docs_elastic_json_pickle.p', 'rb')

# dump information to that file
data = pickle.load(file)

# close the file
file.close()

# %%
len(data)
# Out:
# 148

# %%
type(data)
# Out:
# list

# %%
for i in data:
    print(i)
# Out:
# {"creation_dt": "2015-05-22", "processing_level": "L1GT", "red": "s3://dev-usgs-landsat/collection1/level2/albers/oli-tirs/2015/046/028/LC08_L1GT_046028_20150522_20170228_01_A2/LC08_L1GT_046028_20150522_20170228_01_A2_sr_band4.tif", "green": "s3://dev-usgs-landsat/collection1/level2/albers/oli-tirs/2015/046/028/LC08_L1GT_046028_20150522_20170228_01_A2/LC08_L1GT_046028_20150522_20170228_01_A2_sr_band3.tif", "blue": "s3://dev-usgs-landsat/collection1/level2/albers/oli-tirs/2015/046/028/LC08_L1GT_046028_20150522_20170228_01_A2/LC08_L1GT_046028_20150522_20170228_01_A2_sr_band2.tif", "nir": "s3://dev-usgs-landsat/collection1/level2/albers/oli-tirs/2015/046/028/LC08_L1GT_046028_20150522_20170228_01_A2/LC08_L1GT_046028_20150522_20170228_01_A2_sr_band5.tif", "pixel_qa": "s3://dev-usgs-landsat/collection1/level2/albers/oli-tirs/2015/046/028/LC08_L1GT_046028_20150522_20170228_01_A2/LC08_L1GT_046028_20150522_20170228_01_A2_pixel_qa.tif", "ul": {"lat": "47.501196", "lon": "-124.485947"}, "lr": {
# ...
